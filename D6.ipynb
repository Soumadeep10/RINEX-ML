# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumadeep10/RINEX-ML/blob/main/D6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS- Is a Python library, usead to organise and create dataframe,series
#DATASET - Collection of data in Excel,Txt,Tsv,etc formats
#DATAFRAME - Table Data
#SERIES - Column(One Dimenssional  Array)

# %%
mydataset = {
    'cars':['BMW','VOLVO','FORD'],
    'passings':[3,7,2]
}

# %%
type(mydataset)
# Out:
# dict

# %%
import pandas as pd
df = pd.DataFrame(mydataset)
df
# Out:
#     cars  passings
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a = [1,7,2,6]
myvar = pd.Series(a)
myvar # Column 1,7,2,6 is series & 0,1,2,3 - index
# Out:
# 0    1
# 1    7
# 2    2
# 3    6
# dtype: int64

# %%
type(myvar)
# Out:
# pandas.core.series.Series

# %%
#So in pandas we can easily change the index of particular series
a =[1,7,2,6]
myvar1 = pd.Series(a,index = ['w','x','y','z'])
myvar1
# Out:
# w    1
# x    7
# y    2
# z    6
# dtype: int64

# %%
type(myvar1)
# Out:
# pandas.core.series.Series

# %%
calories = {'day1':420,'day2':380,'day3':395}
calories
# Out:
# {'day1': 420, 'day2': 380, 'day3': 395}

# %%
a1 = pd.Series(calories)
a1
# Out:
# day1    420
# day2    380
# day3    395
# dtype: int64

# %%
sports1 = pd.Series([1,2,3,4],index = ['Cricket','Football','Hockey','Golf'])
sports1
# Out:
# Cricket     1
# Football    2
# Hockey      3
# Golf        4
# dtype: int64

# %%
sports2 = pd.Series([1,2,5,4],index = ['Cricket','Basketball','Baseball','Golf'])
sports2
# Out:
# Cricket       1
# Basketball    2
# Baseball      5
# Golf          4
# dtype: int64

# %%
s = sports1 + sports2 
s
#NAN = Not A Value
#In few datsets, if ever we have NAN values, then those are considered as either null values or missing data
#The sports are added when the
# Out:
# Baseball      NaN
# Basketball    NaN
# Cricket       2.0
# Football      NaN
# Golf          8.0
# Hockey        NaN
# dtype: float64

# %%
# Whenever NAN comes ito picture, integers are converted into float

# %%
import numpy as np
df = pd.DataFrame({'Cricket':[1,2,np.nan,4,6,7,2,np.nan],
                 'Baseball':[5,np.nan,np.nan,5,7,2,4,5],
                 'Tennis':[1,2,3,4,5,6,7,8]})
df
# Out:
#    Cricket  Baseball  Tennis
# 0      1.0       5.0       1
# 1      2.0       NaN       2
# 2      NaN       NaN       3
# 3      4.0       5.0       4
# 4      6.0       7.0       5
# 5      7.0       2.0       6
# 6      2.0       4.0       7
# 7      NaN       5.0       8

# %%
# I just want to drop all the NAN values
df.dropna()
# Out:
#    Cricket  Baseball  Tennis
# 0      1.0       5.0       1
# 3      4.0       5.0       4
# 4      6.0       7.0       5
# 5      7.0       2.0       6
# 6      2.0       4.0       7

# %%
df=df.fillna(value = 0)
df
# Out:
#    Cricket  Baseball  Tennis
# 0      1.0       5.0       1
# 1      2.0       0.0       2
# 2      0.0       0.0       3
# 3      4.0       5.0       4
# 4      6.0       7.0       5
# 5      7.0       2.0       6
# 6      2.0       4.0       7
# 7      0.0       5.0       8

# %%
#Exploration Data Analysis - EDA- We find insights, we come conclusions - Pre machine learning
#Datasets - https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220522%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220522T044705Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...

# %%
# create a dataframe 
import pandas as pd
df =  pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220522%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220522T044705Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...',sep = '\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
df.shape#attribute - (59,7) - 59 rows, 7 Columns
# Out:
# (59, 7)

# %%
df.size
# Out:
# 413

# %%
df.info() #method  - it givees all the information about my dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
#Find out the missing values
df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
fname = df['fruit_name'] # or df.fruit_name will print same output # i have created a variable called fname and put fruit_name columns's data
fname
# Out:
# 0        apple
# 1        apple
# 2        apple
# 3     mandarin
# 4     mandarin
# 5     mandarin
# 6     mandarin
# 7     mandarin
# 8        apple
# 9        apple
# 10       apple
# 11       apple
# 12       apple
# 13       apple
# 14       apple
# 15       apple
# 16       apple
# 17       apple
# 18       apple
# 19       apple
# 20       apple
# 21       apple
# 22       apple
# 23       apple
# 24      orange
# 25      orange
# 26      orange
# 27      orange
# 28      orange
# 29      orange
# 30      orange
# 31      orange
# 32      orange
# 33      orange
# 34      orange
# 35      orange
# 36      orange
# 37      orange
# 38      orange
# 39      orange
# 40      orange
# 41      orange
# 42      orange
# 43       lemon
# 44       lemon
# 45       lemon
# 46       lemon
# 47       lemon
# 48       lemon
# 49       lemon
# 50       lemon
# 51       lemon
# 52       lemon
# 53       lemon
# 54       lemon
# 55       lemon
# 56       lemon
# 57       lemon
# ...

# %%
#slicing 
# slice row indexs from 25-43 
df[25:44]  # 25 - is inclusive & 44 - exclusive
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# ...

# %%
#slice row indexs from 25 - 43 & column indexs 0 and 1
#df.iloc[rows,cols]
df.iloc[25:44,0:2]
# Out:
#     fruit_label fruit_name
# 25            3     orange
# 26            3     orange
# 27            3     orange
# 28            3     orange
# 29            3     orange
# 30            3     orange
# 31            3     orange
# 32            3     orange
# 33            3     orange
# 34            3     orange
# 35            3     orange
# 36            3     orange
# 37            3     orange
# 38            3     orange
# 39            3     orange
# 40            3     orange
# 41            3     orange
# 42            3     orange
# 43            4      lemon

# %%
#How many unique fruit names do we have?
fname = df.fruit_name.unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
# want to know the exact count of every fruit
fsize = df.groupby('fruit_name').size()
fsize
# by default .groupby sorts the fruit name into alphabetical order 
#but matplotlib doesnot follows alphabetical order
# Out:
# fruit_name
# apple       19
# lemon       16
# mandarin     5
# orange      19
# dtype: int64

# %%
#Visualisation -  graph is not correct
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color = ['red','pink','green','orange'])
# Out:
# <BarContainer object of 4 artists>

# %%
fsize = df.groupby('fruit_name',sort = False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
#Visualisation - Now we got the correct graph 
import matplotlib.pyplot as plt
plt.bar(fname,fsize,color = ['red','pink','green','orange'])
# Out:
# <BarContainer object of 4 artists>
